# %% [markdown]
# ## Load Libraries

# %%
import os
import locale
import modal
from dotenv import load_dotenv

# %% [markdown]
# ## Load Environment Key

# %%
try:
    script_dir = os.path.dirname(os.path.abspath(__file__))
except NameError:
    script_dir = os.getcwd()

# Go up one level to the project folder
project_dir = os.path.dirname(script_dir)
env_path = os.path.join(project_dir, "env_keys", ".env")

# Access the variable
load_dotenv(dotenv_path=env_path)

modal_token_id = os.getenv("MODAL_TOKEN_ID")
modal_token = os.getenv("MODAL_TOKEN")

print("API Keys loaded:")
print(f"Model ID: {modal_token_id is not None}")
print(f"Model Key: {modal_token is not None}")
# Out:
# API Keys loaded:
# Model ID: True
# Model Key: True

# %% [markdown]
# ## Authenticate Modal

# %%
# !modal token set --token-id $modal_token_id --token-secret $modal_token
# Out:
# Verifying token against https://api.modal.com
# Token verified successfully!
# ⠋ Storing token
#
# Token written to C:\Users\REDTECH/.modal.toml in profile kumudithasilva.
# Warning: The MODAL_TOKEN_ID environment variable is set; this will override
# your new credentials.

# %% [markdown]
# ## Specialist Agent

# %%
stream_game = """

Game: Archean
Peak CCU: 16
Required Age: 0
DLC Count: 0
Supports Windows: True
Supports Mac: False
Supports Linux: True
Positive Reviews: 159
Negative Reviews: 22
Achievements: 0
Recommendations: 207
Release Date: 2024-5-16
Estimated Owners: 100000 - 200000
Languages Supported: 5
Developers: 2
Publishers: 2
Categories: 9
Genres: 3
Description: Build spacecraft and solve challenges in a physics sandbox.

Price is $
"""

# %%
import logging
root = logging.getLogger()
root.setLevel(logging.INFO)

# %%
from agents.specialist_agent import SpecialistAgent

# %%
agent = SpecialistAgent()

# %%
agent.price(stream_game)
# Out:
# INFO:root:[Specialist Agent] Specialist Agent is calling remote fine-tuned model
# INFO:root:[Specialist Agent] Specialist Agent completed - predicting $7.00
# 7.0
